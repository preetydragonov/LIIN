# %%
from theano.sandbox import cuda
from

# %%
# %matplotlib inline
import utils; reload(utils)
from utils import *
from __future__ import division, print_function
# Out:
# Using TensorFlow backend.

# %%
#path = "data/ml-20m/"
path = "../data/mind_user_answers/workfile.csv"
model_path = "../data/mind_user_answers/model/"
print (os.path.exists(path))
if not os.path.exists(model_path): 
    os.mkdir(model_path)
batch_size=64
# Out:
# True

# %%
import pandas as pd
import numpy as np
import scipy
import shlex
## shlex for making comma
from sklearn import preprocessing, cross_validation, neighbors

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


from sklearn import decomposition
from sklearn import datasets

# %% [markdown]
# ## Data Preprocess

# %%
path = "../data/mind_user_answers/workfile.csv"

# %%
ratings = pd.read_csv(path)

# %%
ratings
# Out:
#              U9 2015-11-16 20:44:38 2015-11-16.1 20:50:07
# 0            U9        Q96        N          NaN      NaN
# 1            U9         Q4        Y          NaN      NaN
# 2            U9        Q10        N          NaN      NaN
# 3            U9        Q44        Y          NaN      NaN
# 4            U9        Q51        N          NaN      NaN
# 5            U9        Q95        Y          NaN      NaN
# 6            U9        Q43        N          NaN      NaN
# 7            U9        Q57        N          NaN      NaN
# 8            U9        Q67        N          NaN      NaN
# 9            U9        Q99        Y          NaN      NaN
# 10           U9        Q78        N          NaN      NaN
# 11           U9        Q46        N          NaN      NaN
# 12           U9        Q21        N          NaN      NaN
# 13           U9        Q52        Y          NaN      NaN
# 14           U9        Q31        Y          NaN      NaN
# ...

# %%
ratings.columns
# Out:
# Index([u'U9', u'2015-11-16', u'20:44:38', u'2015-11-16.1', u'20:50:07'], dtype='object')

# %%
ratings = ratings.drop('2015-11-16.1', axis=1)

# %%
ratings = ratings.drop('20:50:07', axis=1)

# %%
ratings
# Out:
#              U9 2015-11-16 20:44:38
# 0            U9        Q96        N
# 1            U9         Q4        Y
# 2            U9        Q10        N
# 3            U9        Q44        Y
# 4            U9        Q51        N
# 5            U9        Q95        Y
# 6            U9        Q43        N
# 7            U9        Q57        N
# 8            U9        Q67        N
# 9            U9        Q99        Y
# 10           U9        Q78        N
# 11           U9        Q46        N
# 12           U9        Q21        N
# 13           U9        Q52        Y
# 14           U9        Q31        Y
# 15           U9        Q50        Y
# 16           U9        Q48        Y
# 17           U9        Q76        Y
# 18           U9        Q98        N
# 19           U9         Q1        Y
# 20           U9         Q3        N
# 21           U9        Q69        N
# 22           U9        Q86        N
# 23           U9        Q40        N
# 24           U9        Q88        N
# ...

# %%
ratings = ratings.rename(index=str, columns={"U9": "Users_ID", "2015-11-16": "Questions", "20:44:38" : "Y_or_N"})

# %%
ratings = ratings[(ratings.Y_or_N == 'Y') | (ratings.Y_or_N == 'N')]

# %%
ratings
# Out:
#         Users_ID Questions Y_or_N
# 0             U9       Q96      N
# 1             U9        Q4      Y
# 2             U9       Q10      N
# 3             U9       Q44      Y
# 4             U9       Q51      N
# 5             U9       Q95      Y
# 6             U9       Q43      N
# 7             U9       Q57      N
# 8             U9       Q67      N
# 9             U9       Q99      Y
# 10            U9       Q78      N
# 11            U9       Q46      N
# 12            U9       Q21      N
# 13            U9       Q52      Y
# 14            U9       Q31      Y
# 15            U9       Q50      Y
# 16            U9       Q48      Y
# 17            U9       Q76      Y
# 18            U9       Q98      N
# 19            U9        Q1      Y
# 20            U9        Q3      N
# 21            U9       Q69      N
# 22            U9       Q86      N
# 23            U9       Q40      N
# 24            U9       Q88      N
# 25            U9       Q45      Y
# ...

# %%
ratings['Users_ID'] = ratings['Users_ID'].str.replace(r'\D+', '').astype('int')

# %%
ratings['Questions'] = ratings['Questions'].str.replace(r'\D+', '').astype('int')

# %%
ratings['Y_or_N'] = ratings['Y_or_N'].str.replace('N', '0')

# %%
ratings['Y_or_N'] = ratings['Y_or_N'].str.replace('Y', '1')

# %%
ratings['Y_or_N'] = ratings['Y_or_N'].str.replace(r'\D+', '').astype('int')

# %%
ratings
# Out:
#          Users_ID  Questions  Y_or_N
# 0               9         96       0
# 1               9          4       1
# 2               9         10       0
# 3               9         44       1
# 4               9         51       0
# 5               9         95       1
# 6               9         43       0
# 7               9         57       0
# 8               9         67       0
# 9               9         99       1
# 10              9         78       0
# 11              9         46       0
# 12              9         21       0
# 13              9         52       1
# 14              9         31       1
# 15              9         50       1
# 16              9         48       1
# 17              9         76       1
# 18              9         98       0
# 19              9          1       1
# 20              9          3       0
# 21              9         69       0
# 22              9         86       0
# 23              9         40       0
# ...

# %% [markdown]
# ratings = ratings.sort(['Questions','Users_ID'], ascending=[True, True])

# %% [markdown]
# # Model 1. Using Latent Factor[also used in Movie Recommendation System]

# %%
n_factors = 50

# %%
np.random.seed = 42

# %%
msk = np.random.rand(len(ratings)) < 0.8
trn = ratings[msk]
val = ratings[~msk]

# %%
cross = pd.crosstab(ratings.Users_ID, ratings.Questions, ratings.Y_or_N , aggfunc=np.sum)

# %%
n_users = len(cross)
n_questions = len(cross.columns)

# %%
len(cross.columns)
# Out:
# 100

# %%
len(cross)
# Out:
# 45192

# %%
user_in = Input(shape=(1,), dtype='int64', name='user_in')
u = Embedding(n_users, n_factors, input_length=1, W_regularizer=l2(1e-4))(user_in)

question_in = Input(shape=(1,), dtype='int64', name='movie_in')
m = Embedding(n_questions, n_factors, input_length=1, W_regularizer=l2(1e-4))(question_in)

# %%
# Out:
# 100

# %%
49467 in trn.Users_ID.values
# Out:
# True

# %%
x = merge([u, m], mode='dot')
x = Flatten()(x)
model = Model([user_in, question_in], x)
model.compile(Adam(0.001), loss='mse')

# %%
model

# %%
model.fit([trn.Users_ID, trn.Questions], trn.Y_or_N, batch_size=64, nb_epoch=1, 
          validation_data=([val.Users_ID, val.Questions], val.Y_or_N))
# Out:
# Train on 3615269 samples, validate on 903931 samples
# Epoch 1/1
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-77-4a7629c2647a> in <module>()
#       1 model.fit([trn.Users_ID, trn.Questions], trn.Y_or_N, batch_size=64, nb_epoch=1,
# ----> 2           validation_data=([val.Users_ID, val.Questions], val.Y_or_N))
#
# /Users/choelinbeom/anaconda/lib/python2.7/site-packages/keras/engine/training.pyc in fit(self, x, y, batch_size, nb_epoch, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch)
#    1194                               val_f=val_f, val_ins=val_ins, shuffle=shuffle,
#    1195                               callback_metrics=callback_metrics,
# -> 1196                               initial_epoch=initial_epoch)
#    1197
# ...

# %%
# Out:
# <bound method Model.summary of <keras.engine.training.Model object at 0x1214a3590>>

# %% [markdown]
# df.ix[df.index.get_level_values('Period') != 0, 'Value'] = 0

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-a54fbc0fd510> in <module>()
#       6     trn_temp = temp[msk]
#       7     val_temp = temp[~msk]
# ----> 8     conc = r_[conc, trn_temp]
#
# NameError: name 'r_' is not defined

# %% [markdown]
# masking부터 진행ㅎ

# %%
# Out:
# array([ True,  True,  True,  True,  True,  True, False,  True,  True,
#        False,  True, False,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True, False,  True,  True,
#         True,  True,  True], dtype=bool)

# %%
# Out:
# 4519200

# %%
# Out:
# 1

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-257b2fbd3633> in <module>()
# ----> 1 df.drop('U9', axis=1)
#
# /Users/choelinbeom/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in drop(self, labels, axis, level, inplace, errors)
#    1875                 new_axis = axis.drop(labels, level=level, errors=errors)
#    1876             else:
# -> 1877                 new_axis = axis.drop(labels, errors=errors)
#    1878             dropped = self.reindex(**{axis_name: new_axis})
#    1879             try:
#
# /Users/choelinbeom/anaconda/lib/python2.7/site-packages/pandas/indexes/base.pyc in drop(self, labels, errors)
#    3049             if errors != 'ignore':
#    3050                 raise ValueError('labels %s not contained in axis' %
# -> 3051                                  labels[mask])
#    3052             indexer = indexer[~mask]
# ...

# %% [markdown]
# Question을 index로 가질 경우, 사람들이 다 다른 경우를 제시할 수

# %%
user_in = Input(shape=(1,), dtype='int64', name='user_in')
u = Embedding(n_users, n_factors, input_length=1, W_regularizer=l2(1e-4))(user_in)
movie_in = Input(shape=(1,), dtype='int64', name='movie_in')
m = Embedding(n_movies, n_factors, input_length=1, W_regularizer=l2(1e-4))(movie_in)

# %%
x = merge([u, m], mode='dot')
x = Flatten()(x)
model = Model([user_in, movie_in], x)
model.compile(Adam(0.001), loss='mse')

# %%
model.fit([trn.userId, trn.movieId], trn.rating, batch_size=64, nb_epoch=1, 
          validation_data=([val.userId, val.movieId], val.rating))

# %%
model.optimizer.lr=0.01

# %%
model.fit([trn.userId, trn.movieId], trn.rating, batch_size=64, nb_epoch=3, 
          validation_data=([val.userId, val.movieId], val.rating))

# %%
model.optimizer.lr=0.001

# %%
model.fit([trn.userId, trn.movieId], trn.rating, batch_size=64, nb_epoch=3, 
          validation_data=([val.userId, val.movieId], val.rating))

# %% [markdown]
# # Learn With Simple Regressions

# %% [markdown]
# # Learn With Embeddings

# %%
batch_size=100

# %% [markdown]
# # 상관 관계 분석

# %% [markdown]
# # 주성분 분석

# %% [markdown]
# # 시각화
